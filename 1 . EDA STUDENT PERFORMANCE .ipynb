# %% [markdown]
# ## Student Performance Indicator

# %% [markdown]
# #### Life cycle of Machine learning Project
#
# - Understanding the Problem Statement
# - Data Collection
# - Data Checks to perform
# - Exploratory data analysis
# - Data Pre-Processing
# - Model Training
# - Choose best model

# %% [markdown]
# ### 1) Problem statement
# - This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course.
#
#
# ### 2) Data Collection
# - Dataset Source - https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasetId=74977
# - The data consists of 8 column and 1000 rows.

# %% [markdown]
# ### 2.1 Import Data and Required Packages
# ####  Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv('data/data.csv')

# %% [markdown]
# #### Show Top 5 Records

# %%
df.head()
# Out:
#    Gender Height  Weight  Bust/Chest Cup Size  Waist  Hips  Body Shape Index
# 0    Male   5'9"      53          34      NaN     30    30                 1
# 1  Female   6'5"      84          43        A     26    26                 2
# 2  Female  5'10"      97          37        D     33    40                 4
# 3    Male   6'4"      97          45      NaN     41    47                 4
# 4    Male   5'4"      57          31      NaN     28    32                 4

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (3000, 8)

# %% [markdown]
# ### 3.1 Check Missing values

# %%
df.isna().sum()
# Out:
# Gender                 0
# Height                 0
# Weight                 0
# Bust/Chest             0
# Cup Size            1444
# Waist                  0
# Hips                   0
# Body Shape Index       0
# dtype: int64

# %% [markdown]
# #### There are no missing values in the data set

# %% [markdown]
# ### 3.2 Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There are no duplicates  values in the data set

# %% [markdown]
# ### 3.3 Check data types

# %%
# Check Null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Gender            3000 non-null   object
#  1   Height            3000 non-null   object
#  2   Weight            3000 non-null   int64
#  3   Bust/Chest        3000 non-null   int64
#  4   Cup Size          1556 non-null   object
#  5   Waist             3000 non-null   int64
#  6   Hips              3000 non-null   int64
#  7   Body Shape Index  3000 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 187.6+ KB

# %% [markdown]
# ### 3.4 Checking the number of unique values of each column

# %%
df.nunique()
# Out:
# Gender               2
# Height              21
# Weight              83
# Bust/Chest          29
# Cup Size             8
# Waist               33
# Hips                34
# Body Shape Index     7
# dtype: int64

# %% [markdown]
# ### 3.5 Check statistics of data set

# %%
df.describe()
# Out:
#             Weight   Bust/Chest        Waist         Hips  Body Shape Index
# count  3000.000000  3000.000000  3000.000000  3000.000000       3000.000000
# mean     72.622667    38.614667    34.062667    38.893000          2.058333
# std      16.387672     6.432779     6.530362     7.038376          1.555122
# min      36.000000    26.000000    19.000000    20.000000         -1.000000
# 25%      60.000000    33.000000    29.000000    34.000000          1.000000
# 50%      71.000000    38.000000    34.000000    39.000000          2.000000
# 75%      83.000000    44.000000    39.000000    44.000000          3.000000
# max     119.000000    54.000000    51.000000    53.000000          5.000000

# %% [markdown]
# ### 3.7 Exploring Data

# %%
df.head()
# Out:
#    Gender Height  Weight  Bust/Chest Cup Size  Waist  Hips  Body Shape Index
# 0    Male   5'9"      53          34      NaN     30    30                 1
# 1  Female   6'5"      84          43        A     26    26                 2
# 2  Female  5'10"      97          37        D     33    40                 4
# 3    Male   6'4"      97          45      NaN     41    47                 4
# 4    Male   5'4"      57          31      NaN     28    32                 4

# %%
print("Categories in 'gender' variable:     ",end=" " )
print(df['Gender'].unique())

print("Categories in 'Height' variable:  ",end=" ")
print(df['Height'].unique())

print("Categories in'Weight' variable:",end=" " )
print(df['Weight'].unique())

print("Categories is Bust/Chest variable:     ",end=" " )
print(df['Bust/Chest'].unique())

print("Categories is Cup Size variable:     ",end=" " )
print(df['Cup Size'].unique())

print("Categories is Waist variable:     ",end=" " )
print(df['Waist'].unique())

print("Categories in 'Hips' variable:     ",end=" " )
print(df['Hips'].unique())

print("Categories in 'Body Shape Index' variable:     ",end=" " )
print(df['Body Shape Index'].unique())
# Out:
# Categories in 'gender' variable:      ['Male' 'Female']
# Categories in 'Height' variable:   ['5\'9"' '6\'5"' '5\'10"' '6\'4"' '5\'4"' '6\'0"' '5\'7"' '5\'11"' '6\'1"'
#  '6\'6"' '5\'5"' '5\'6"' '4\'11"' '5\'1"' '4\'10"' '5\'0"' '5\'8"' '6\'3"'
#  '5\'2"' '5\'3"' '6\'2"']
# Categories in'Weight' variable: [ 53  84  97  57  67  79 101  93  75  77  65  71  61  52  89  74  90  56
#   68  81 111  72  95  44  48 112  80  82  78  60  69  51  91  64  66 109
#   45  85  76  70  88  63 102  54  87  47  83  99 103  86  73  43  42 104
#   46  59  98  62  94  50 106 100  49 105  55  58  41  96 117  40 107 108
#   92  38 110 113 114 116 115  39  36 119 118]
# Categories is Bust/Chest variable:      [34 43 37 45 31 42 50 52 51 33 38 35 39 36 41 32 29 47 44 48 40 46 49 30
#  28 27 26 53 54]
# Categories is Cup Size variable:      [nan 'A' 'D' 'F' 'AA' 'C' 'E' 'DD' 'B']
# Categories is Waist variable:      [30 26 33 41 28 39 40 35 32 31 36 38 34 25 29 24 37 23 42 27 47 43 46 44
# ...

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 5 numerical features : ['Weight', 'Bust/Chest', 'Waist', 'Hips', 'Body Shape Index']
#
# We have 3 categorical features : ['Gender', 'Height', 'Cup Size']

# %%
df.head(2)
# Out:
#    Gender Height  Weight  Bust/Chest Cup Size  Waist  Hips  Body Shape Index
# 0    Male   5'9"      53          34      NaN     30    30                 1
# 1  Female   6'5"      84          43        A     26    26                 2

# %% [markdown]
# ### 3.8 Adding columns for "Body Size"

# %%
size_mapping = {
    0: 'S',
    1: 'M',
    2: 'L',
    3: 'XL',
    4: 'XXL',
}

df['BodySize'] = df['Body Shape Index'].map(size_mapping)
print(df[['Body Shape Index', 'BodySize']])
# Out:
#       Body Shape Index BodySize
# 0                    1        M
# 1                    2        L
# 2                    4      XXL
# 3                    4      XXL
# 4                    4      XXL
# ...                ...      ...
# 2995                 0        S
# 2996                 0        S
# 2997                 3       XL
# 2998                 3       XL
# 2999                 4      XXL
#
# [3000 rows x 2 columns]

# %% [markdown]
# #### 4.1.1 Histogram & KDE

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='BodySize',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='BodySize',kde=True,hue='Gender')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='BodySize',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='BodySize',kde=True,hue='Gender')
plt.show()

# %% [markdown]
# #####  Insights
# - Female students tend to perform well then male students.

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='BodySize',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='BodySize',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='BodySize',kde=True,hue='lunch')
plt.show()

# %% [markdown]
# #####  Insights
# - Standard lunch helps perform well in exams.
# - Standard lunch helps perform well in exams be it a male or a female.

# %% [markdown]
# #####  Insights
# - In general parent's education don't help student perform well in exam.
# - 2nd plot shows that parent's whose education is of associate's degree or master's degree their male child tend to perform well in exam
# - 3rd plot we can see there is no effect of parent's education on female students.

# %% [markdown]
# #####  Insights
# - Students of group A and group B tends to perform poorly in exam.
# - Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female

# %% [markdown]
# #### 4.2 Maximumum score of students in all three subjects

# %% [markdown]
# #### Insights
# - From the above three plots its clearly visible that most of the students score in between 60-80 in Maths whereas in reading and writing most of them score from 50-80
